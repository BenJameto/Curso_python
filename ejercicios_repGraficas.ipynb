# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## distribucion normal
#
# ### Especifica la media y la desviación estándar de la distribución normal
# media = 0
# desviacion_estandar = 1
#
# ### Genera 10 valores aleatorios que sigan una distribución normal
# valores_aleatorios = np.random.normal(media, desviacion_estandar, 10)
#
# print(valores_aleatorios)

# %%
valores = np.random.normal(0, 1, 1000)

# %%
valores1= np.random.randn(1000)

# %%
#plt.hist(valores)
sns.boxplot(valores)
# Out:
# <Axes: >

# %%
#plt.hist(valores1)
sns.boxplot(valores1)
# Out:
# <Axes: >

# %% [markdown]
# # ejercicio 2
#
# ### Especifica el rango de números enteros
# limite_inferior = 1
# limite_superior = 100
#
# #### Genera un arreglo unidimensional de números enteros aleatorios dentro del rango especificado
# arreglo_enteros_aleatorios = np.random.randint(limite_inferior, limite_superior, size=10)
#
# print(arreglo_enteros_aleatorios)

# %%
enteros=np.random.randint(0,500,100)

# %%
sns.boxplot(enteros)
# Out:
# <Axes: >

# %%
plt.hist(enteros)
# Out:
# (array([15.,  7., 11., 11.,  7., 14.,  4., 13.,  7., 11.]),
#  array([  2. ,  50.5,  99. , 147.5, 196. , 244.5, 293. , 341.5, 390. ,
#         438.5, 487. ]),
#  <BarContainer object of 10 artists>)

# %%
# Out:
# array([[280, 249, 150,  69, 356, 248, 428, 159, 132,  41],
#        [123, 191, 380, 361,  77, 443, 272, 481,   4, 234],
#        [453, 379, 374,  92, 190, 139,   4, 193, 208, 472],
#        [179, 431,  49, 232, 329, 379, 369, 449, 289,  39],
#        [446, 211, 483, 467, 201, 281, 121, 145, 252, 366],
#        [162, 487,  89,  89, 245,  18, 392, 433,  28, 436],
#        [362, 142, 132, 181, 266,  48, 117, 284,  35, 180],
#        [ 59, 278, 424, 274,   3, 224, 375,  34, 486, 441],
#        [315, 359,  63, 415, 136, 169, 251, 346, 197,   2],
#        [119, 328, 384, 129,  15,  21, 282, 311,  19, 173]])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
enteros=np.random.randint(0,500,100)
matriz_enteros=enteros.reshape(10,10)
sns.heatmap(matriz_enteros, annot=True, fmt='d', cmap='YlOrRd')
plt.xlabel('Columnas')
plt.ylabel('Filas')
plt.show()
